# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys

chrome_options = webdriver.ChromeOptions()
chrome_options.add_argument('--no-sandbox')
# create a new webbrowser session
driver = webdriver.Chrome('G:\\My Drive\\Cs\\2019_01\\SocialNetworkAnalysis\\chromedriver for chrome78\\chromedriver')
driver.implicitly_wait(30)
driver.maximize_window()

# %%
import random
import os.path

output_filename = 'postcomment.csv'
   
pageNameOrId = 'khaosod'  #'khaosod' #'MorningNewsTV3' #'thairath' #'khaosod' 
postId = '4322590284424564'  #'4324893260860933' '4322590284424564'
source_url = 'https://www.facebook.com/pg/%s/posts/%s/' % (pageNameOrId,postId)    
#activity_list = find_all_activity1(source_url)
print(source_url)

# %%
from bs4 import BeautifulSoup 
import json
import time
from datetime import datetime
import pandas as pd

fetch_url = 'https://www.facebook.com/pg/%s/posts/%s/' % (pageNameOrId,postId) 
driver.get(fetch_url)
l = 0
last_l = -1
comment_list = []

userIds = ''
commentIds = ''
commentTimes = datetime.now()
commentText = ''      
commentInteractionCount = 0

dataa = driver.find_elements_by_class_name("_3w53") #all comment
data = dataa[0]
soup = BeautifulSoup(data.get_attribute('innerHTML'), 'html.parser')
divs = soup.find_all('div', {'class': '_42ef'}) #one comment   
for div in divs[1:]:
    for div_content in div.find_all('div',{'class':'_6c7i'}):
        comment_text = div.find_all('span',{'class' : '_3l3x'})
        user_id = div.find_all('a', {'class': '_6qw4'})
        comment_interaction = div.find_all('div',{'class' : '_6cuq'})
                    
        commentText =  [span.getText() for span in comment_text]
        commentInteractionCount = [int(span.getText()) for span in comment_interaction]
        userIds = [a['href'] for a in user_id]
              
    for ul_interact in div.find_all('ul',{'class':'_6coi _6qw9'}) :
        comment_id = div.find_all('a', {'class': '_6qw7'})
        commentIds = [((a['href']).split('?')[1]).split('=')[1] for a in comment_id]
        commentTimes = [int(a.abbr['data-utime']) for a in comment_id] #attribute
        commentTimes = pd.to_datetime(commentTimes[0],unit='s').strftime("%Y-%m-%d %H:%M:%S")
        #datetime.fromtimestamp(commentTimes[0])
            
    print('loop')
    comment_list.append({
        #'post_id' : '1',
        'comment_id': commentIds,
        'comment_time': commentTimes,
        'comment_content' : commentText,      
        'user_id': userIds,
        'comment_like_count' : commentInteractionCount,
        'crawl_timestamp' : datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    }) 
          
#detail = ""
print(comment_list)
#print(len(comment_list), 'data were collected.')

# %%
from bs4 import BeautifulSoup 
import json
import time
from datetime import datetime
import pandas as pd

def find_all_comment(pageNameOrId,postId):
    fetch_url = 'https://www.facebook.com/pg/%s/posts/%s/' % (pageNameOrId,postId) 
    driver.get(fetch_url)
    l = 0
    last_l = -1
    comment_list = []

    userIds = ''
    commentIds = ''
    commentTimes = ''
    commentText = ''      
    commentInteractionCount = 0

    dataa = driver.find_elements_by_class_name("_3w53") #all comment
    data = dataa[0]
    soup = BeautifulSoup(data.get_attribute('innerHTML'), 'html.parser')
    divs = soup.find_all('div', {'class': '_42ef'}) #one comment   
    for div in divs[1:]:
        for div_content in div.find_all('div',{'class':'_6c7i'}):
            comment_text = div.find_all('span',{'class' : '_3l3x'})
            user_id = div.find_all('a', {'class': '_6qw4'})
            comment_interaction = div.find_all('div',{'class' : '_6cuq'})

            commentText =  [span.getText() for span in comment_text]
            commentInteractionCount = [int(span.getText()) for span in comment_interaction] or '0'
            userIds = [a['href'] for a in user_id]

        for ul_interact in div.find_all('ul',{'class':'_6coi _6qw9'}) :
            comment_id = div.find_all('a', {'class': '_6qw7'})
            commentIds = [((a['href']).split('?')[1]).split('=')[1] for a in comment_id]
            commentTimes = [int(a.abbr['data-utime']) for a in comment_id] #attribute
            commentTimes = pd.to_datetime(commentTimes[0],unit='s').strftime("%Y-%m-%d %H:%M:%S")

        #print('loop')
        comment_list.append({
            'post_id' : postId,
            'comment_id': commentIds,
            'comment_time': commentTimes,
            'comment_content' : commentText,      
            'user_id': userIds,
            'comment_like_count' : commentInteractionCount,
            'crawl_timestamp' : datetime.now().strftime("%Y-%m-%d %H:%M:%S")
        }) 

    #detail = ""
    print(comment_list)
    #print(len(comment_list), 'data were collected.')
    return comment_list

# %%
import random
import os.path

output_filename = 'postcomment.csv'
   
pageNameOrId = 'khaosod'  #'khaosod' #'MorningNewsTV3' #'thairath' #'khaosod' 
postId = '4322590284424564'#'2614134468598012'  #'4324893260860933' '4322590284424564'

while True:
    comment_list = find_all_comment(pageNameOrId,postId)
    #print(comment_list) 
    
    file = open(output_filename,'a',encoding='utf-8')
    for c in comment_list:
        #print(c)
        file.write(c['post_id']+','+c['comment_id'][0]+','+c['comment_time']+','+c['comment_content'][0]+','+c['user_id'][0]+','+str(c['comment_like_count'][0])+','+c['crawl_timestamp'] )#+','+c[2]+','+c[3])
        file.write('\n')
    file.close()
# Out:
# [{'post_id': '4322590284424564', 'comment_id': ['4322653344418258'], 'comment_time': '2019-11-09 15:37:08', 'comment_content': ['ถ้าให้ปลูกกัญชาเสรี  รับรองจะเขียวชุ่มชื่นยิ้มหวานกันเลยค่ะ'], 'user_id': ['/panapen.khiaophet'], 'comment_like_count': [6], 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322673911082868'], 'comment_time': '2019-11-09 15:47:30', 'comment_content': ['เขียวลายพรางนิ'], 'user_id': ['/profile.php?id=100011025461196'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4323582934325299'], 'comment_time': '2019-11-10 00:35:49', 'comment_content': ['เขียวเมากินหนมหวาน😂😂😂😂😙'], 'user_id': ['/huan.joktong.5'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322614964422096'], 'comment_time': '2019-11-09 15:27:30', 'comment_content': ['ทุกวันนี้ก็เขียวทั้งประเทศอยู่แล้วครับประชาชนหน้าเขียวเพราะการปกครองของคนสีเขียวขี้ม้า ที่พวกท่านสนับสนุน'], 'user_id': ['/chartchai.srivisut'], 'comment_like_count': [7], 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322820887734837'], 'comment_time': '2019-11-09 17:03:09', 'comment_content': ['เปลี่ยนโทษคดีตัดไม้ทำลายป่าเป็นปลุกจ้นไม่ 10 เท่าของโทษนั้นๆ แล้วติดคุกเมื่อปลูกเสร็จแล้ว'], 'user_id': ['/srisua'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322662327750693'], 'comment_time': '2019-11-09 15:41:43', 'comment_content': ['ผมเสนอปลูกหญ้าเยอะๆครับ ลูกพี่ของท่านคงต้องกินอีกหลายปี'], 'user_id': ['/ton.songkrod'], 'comment_like_count': [2], 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322769011073358'], 'comment_time': '2019-11-09 16:35:11', 'comment_content': ['ปลูกหน้าบ้านคนละเล็กคนละน้อยให้ได้ก่อนเถอะค่ะ คนที่ตัดต้นไม้ใหญ่ๆก็น่าจะเป็นพวกนายทุนที่มาจ้างชาวบ้านนะคะ คนธรรมดาจนๆคงทำไม่ได้'], 'user_id': ['/profile.php?id=100016348024445'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322671547749771'], 'comment_time': '2019-11-09 15:46:22', 'comment_content': ['ดูเหมือนขยะ แอร๊ยย ดูเหมือนขยัน 😅'], 'user_id': ['/profile.php?id=100019718178872'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322617634421829'], 'comment_time': '2019-11-09 15:28:45', 'comment_content': ['เขียวพ่อง!!!!!! พื้นที่สีเขียว นายทุนครอบครองหมดแล้ว'], 'user_id': ['/pond.pung.71'], 'comment_like_count': [1], 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322650921085167'], 'comment_time': '2019-11-09 15:36:11', 'comment_content': ['ตรูว่าหยุดทุกอย่างไปคิดว่าทำอย่างไรจะไม่เกิดจังหวัดศรีษะเกษโมเดลต่อเนื่องกับทุกคนในรัฐบาลชุดนี้'], 'user_id': ['/profile.php?id=100010758553285'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322655677751358'], 'comment_time': '2019-11-09 15:38:21', 'comment_content': ['เขึยวจนนักธุรกิจคาของเก่าเจ๊งเป็นแถบๆระวังเจอประท่วงนะขอบอกใวัก่อน'], 'user_id': ['/profile.php?id=100009658931605'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4323096714373921'], 'comment_time': '2019-11-09 19:42:37', 'comment_content': ['มันก็แค่ออกมาพูดให้ดูดีแค่นั้นในเมื่อหัวหน้าใหญ่ทำอะไรไม่เป็นเลย'], 'user_id': ['/profile.php?id=100010560707232'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590284424564', 'comment_id': ['4322676307749295'], 'comment_time': '2019-11-09 15:48:40', 'comment_content': ['ปล่อยนายทุ่สร้างบ้านรุกป่าจนหมดละสิ่งแวดล้อมเป้นพิษหมดแล้ว'], 'user_id': ['/ghritamet.yodtongdee'], 'comment_like_count': '0', 'crawl_timestamp': '2019-11-11 20:04:54'}, {'post_id': '4322590 ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-7-db0519df4f31> in <module>
#      17     for c in comment_list:
#      18         #print(c)
# ---> 19         file.write(c['post_id']+','+c['comment_id'][0]+','+c['comment_time']+','+c['comment_content'][0]+','+c['user_id'][0]+','+str(c['comment_like_count'][0])+','+c['crawl_timestamp'] )#+','+c[2]+','+c[3])
#      20         file.write('\n')
#      21     file.close()
#
# IndexError: list index out of range

# %%
from bs4 import BeautifulSoup 
import json
import time
from datetime import datetime
import pandas as pd

fetch_url = 'https://www.facebook.com/pg/%s/posts/%s/' % (pageNameOrId,postId) 
driver.get(fetch_url)
l = 0
last_l = -1
comment_list = []

userIds = ''
commentIds = ''
commentTimes = datetime.now()
commentText = ''      
commentInteractionCount = 0

dataa = driver.find_elements_by_class_name("_3w53") #all comment
data = dataa[0]
soup = BeautifulSoup(data.get_attribute('innerHTML'), 'html.parser')
divs = soup.find_all('div', {'class': '_42ef'}) #one comment   
for div in divs[1:]:
    for div_content in div.find_all('div',{'class':'_6c7i'}):
        comment_text = div.find_all('span',{'class' : '_3l3x'})
        user_id = div.find_all('a', {'class': '_6qw4'})
        comment_interaction = div.find_all('div',{'class' : '_6cuq'})
                                          
        commentText =  [span.getText() for span in comment_text]
        commentInteractionCount = [int(span.getText()) for span in comment_interaction]
        userIds = [a['href'] for a in user_id]
        
        
        comment_interact =  div.find_all('a')
        comment_interactLink = [a['href'] for a in comment_interact]
        
        #print(comment_interactLink[1])
        
        interact_url = 'https://www.facebook.com%s' % (comment_interactLink[1]) 
        
        #print(interact_url)
        
        driver.get(interact_url)
        detail = driver.find_elements_by_class_name("_4bl7 _4k2o") #all interact : class
        
        print(detail)
        
        soup = BeautifulSoup(detail.get_attribute('innerHTML'), 'html.parser')
        lis = soup.find_all('li') #one interact 
        for li in lis[1:]:
            detail_interact = li.findall('div',{'class':'_3p56'})
            detail_interact_text = [div.getText() for span in detail_interact]
            
            detail_count = li.findall('div',{'class' : '_5i_p'})
            c = 0
            detail_count_num = [c+1 for li in detail_count]
            
            print(detail_interact_text)
            print(detail_count_num)
            #len(soup.find_all("li", recursive=False))
            
            #len(soup.find_all("section", recursive=False))
            
            #count li in ul class = uiList _4kg
              
    for ul_interact in div.find_all('ul',{'class':'_6coi _6qw9'}) :
        comment_id = div.find_all('a', {'class': '_6qw7'})
        commentIds = [((a['href']).split('?')[1]).split('=')[1] for a in comment_id]
        commentTimes = [int(a.abbr['data-utime']) for a in comment_id] #attribute
        commentTimes = pd.to_datetime(commentTimes[0],unit='s').strftime("%Y-%m-%d %H:%M:%S")
        #datetime.fromtimestamp(commentTimes[0])
            
    print('loop')
    comment_list.append({
        #'post_id' : '1',
        'comment_id': commentIds,
        'comment_time': commentTimes,
        'comment_content' : commentText,      
        'user_id': userIds,
        'comment_like_count' : commentInteractionCount,
        'crawl_timestamp' : datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    }) 
          
#detail = ""
print(comment_list)
#print(len(comment_list), 'data were collected.')
# Out:
# []
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-78ecf6229ed0> in <module>
#      46         print(detail)
#      47
# ---> 48         soup = BeautifulSoup(detail.get_attribute('innerHTML'), 'html.parser')
#      49         lis = soup.find_all('li') #one interact
#      50         for li in lis[1:]:
#
# AttributeError: 'list' object has no attribute 'get_attribute'
